# %% [markdown]
# # UB TUBAF MAB2 Datenanalyse
#
# Dieses Notebook analysiert die MAB2-Daten der Universitätsbibliothek TU Bergakademie Freiberg.
#
# ## 🎯 Ziel
# - Parse MAB2-Format (027out.t)
# - Extrahiere bibliographische Daten
# - Vorbereitung für Bestandsvergleich mit VDEH
#
# ## 📚 Datenquelle
# - **Datei**: `027out.t` (MAB2-Binärformat)
# - **Quelle**: UB TU Bergakademie Freiberg Bestandsdaten
# - **Format**: MAB2 (Maschinelles Austauschformat für Bibliotheken)

# %%
# 🛠️ SETUP: Konfiguration und Module laden
import sys
import os
from pathlib import Path

# Projektroot finden
current_dir = Path.cwd()
project_root = None

for parent in [current_dir] + list(current_dir.parents):
    if (parent / 'config.yaml').exists():
        project_root = parent
        break

if project_root is None:
    raise FileNotFoundError("config.yaml nicht gefunden!")

print(f"📁 Projektroot: {project_root}")

# Python-Pfad erweitern
src_path = project_root / 'src'
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

print(f"🔧 Python-Pfad erweitert: {src_path}")
# Out:
# 📁 Projektroot: /media/sz/Data/Bibo/analysis
# 🔧 Python-Pfad erweitert: /media/sz/Data/Bibo/analysis/src

# %%
# 📋 KONFIGURATION LADEN
try:
    from config_loader import load_config
    from pathlib import Path
    
    config = load_config(project_root / 'config.yaml')
    print("✅ Konfiguration geladen")
    
    # UB TUBAF spezifische Konfiguration und Pfade
    ub_config = config.get('data_sources.ub_tubaf', {})
    
    if not ub_config:
        raise ValueError("UB TUBAF Konfiguration nicht gefunden!")
    
    # Stelle sicher, dass alle benötigten Verzeichnisse existieren
    required_dirs = [
        config.get_path('data.root'),
        config.get_path('data.ub_tubaf.raw'),
        config.get_path('data.ub_tubaf.processed'),
        config.get_path('data.ub_tubaf.exports')
    ]
    
    for dir_path in required_dirs:
        if not dir_path.exists():
            print(f"📂 Erstelle Verzeichnis: {dir_path}")
            dir_path.mkdir(parents=True, exist_ok=True)
    
    # Überprüfe den Datenpfad
    data_file = project_root / ub_config.get('path', '')
    if not data_file.exists():
        raise FileNotFoundError(f"Datendatei nicht gefunden: {data_file}")
        
    print(f"📄 UB TUBAF Datenquelle: {ub_config.get('description', 'Keine Beschreibung')}")
    print(f"📂 Dateipfad: {data_file}")
    print(f"🔤 Encoding: {ub_config.get('encoding', 'utf-8')}")
    print(f"📊 Geschätzte Records: {ub_config.get('estimated_records', 'Unbekannt')}")

except ImportError as e:
    print(f"❌ Fehler beim Laden des config_loader Moduls: {e}")
    raise
except ValueError as e:
    print(f"❌ Fehler in der Konfiguration: {e}")
    raise
except FileNotFoundError as e:
    print(f"❌ Datei nicht gefunden: {e}")
    raise
except Exception as e:
    print(f"❌ Unerwarteter Fehler: {e}")
    raise
# Out:
# ✅ Konfiguration geladen: /media/sz/Data/Bibo/analysis/config.yaml
# ✅ Konfiguration geladen
# 📄 UB TUBAF Datenquelle: Bestandsdaten der UB TU Bergakademie Freiberg
# 📂 Dateipfad: /media/sz/Data/Bibo/analysis/data/ub_tubaf/raw/027out.t
# 🔤 Encoding: latin1
# 📊 Geschätzte Records: None

# %%
# 📦 BIBLIOTHEKEN UND PARSER LADEN
import pandas as pd
import matplotlib.pyplot as plt

# MAB2 Parser importieren
from parsers.mab2_parser import MAB2Parser, analyze_mab2_data, get_sample_records_mab2

print("✅ Bibliotheken und Parser geladen")
print("📚 MAB2Parser bereit für UB TUBAF Daten")
# Out:
# ✅ Bibliotheken und Parser geladen
# 📚 MAB2Parser bereit für UB TUBAF Daten

# %%
# 📑 MAB2 BEISPIELDATEN
content = """
### 00499nM2.01200024      h
001 073871532
002a20020501
003 20180317150015
026k073871532
026 GBV073871532
030 e|5z|||z|0035
050 a|||||||||||||
051 n||||||
060 $akartografisches Bild$bcri
061 $aohne Hilfsmittel zu benutzen$bn
062 $aBlatt$bnb
070aBSZ
076bmb
200bBayern / Geologisches Landesamt
310 Geologische Karte von Bayern <1:25000>
331 Geologische Karte von Bayern
335 Bundesrepublik Deutschland
359 hrsg. vom Bayerischen Geologischen Landesamt
407 1 : 25 000
410 München
433 Je Bl. 47,5 x 44,5 cm

### 00599nM2.01200024      u
001 9073875056
002a20020501
003 20230321140005
010 073871532
013k073871532
026k073875058
026 GBV073875058
030 e|5z|||z|00||
050 a|||||||||||||
051 |||||||
060 $akartografisches Bild$bcri
061 $aohne Hilfsmittel zu benutzen$bn
062 $aBlatt$bnb
070aBSZ
076bod
076dkart
081 Geologische Karte von Bayern <1:25000>
081aLinderhof ; 1
089 8431, 1
090 8431.1967
100bKuhnert, Christian ¬[Bearb.]¬
200bBayern / Geologisches Landesamt
331 [Karte]
359 bearb. von Ch. Kuhnert
370aGeologische Karte von Bayern <1:25000>
370aLinderhof
407 1 : 25 000
410 München
425 1967
425a1967
433 1 Kt

### 00481nM2.01200024      h
001 9125700332
002a19930613
003 20230519125958
026k125700334
026 GBV125700334
030 a|5z|||z|0037
036aXA-DDDE
037bger
050 a|||||||||||||
051 n||||||
060 $aText$btxt
061 $aohne Hilfsmittel zu benutzen$bn
062 $aBand$bnc
070aBSZ
076bmb
200bDeutschland <DDR> / Amt für Standardisierung, Messwesen und Warenprüfung
202b191578665
331 Verzeichnis staatlicher Standards der DDR
410 Berlin
412 Verl. für Standardisierung
425 1986-
425a1986
540aISBN 3-7405-0071-9

### 00718nM2.01200024      u
001 9162859218
002a19940909
003 20230519130014
010 9125700332
013k125700334
013s9125700332
026k16285921X
026 GBV16285921X
030 e|5z|||z|00||
036aXA-DDDE
037bger
050 a|||||||||||||
051 |||||||
060 $aText$btxt
061 $aohne Hilfsmittel zu benutzen$bn
062 $aBand$bnc
064a$aVerzeichnis$9210051078
070aBSZ
076bod
081 Verzeichnis staatlicher Standards der DDR
089 1
090 1.1989
200bDeutschland <DDR> / Amt für Standardisierung, Messwesen und Warenprüfung
202b191578665
331 Sachteil (2.0.) - (662.0)
410 Berlin
412 Verl. für Standardisierung
425 1989
425a1989
433 550 S.
540aISBN 3-7405-0072-7
902g  208896155           Deutschland
902s  212249827           Norm
902s  210164832           TGL
904aSWB
"""

print("✅ MAB2 Beispieldaten geladen")
# Out:
# ✅ MAB2 Beispieldaten geladen

# %%
# 🔍 MAB2 Parser Implementierung
import re
import pandas as pd
from typing import Optional, Dict, List

class SimpleMab2Parser:
    """Ein einfacher Parser für MAB2-Datensätze"""
    
    def __init__(self):
        # Wichtige MAB2-Felder für die Extraktion
        self.key_fields = {
            '001': 'id',
            '100': 'author',
            '200': 'institution',
            '331': 'title',
            '425': 'year',
            '410': 'place',
            '412': 'publisher',
            '433': 'physical_desc',
            '540': 'isbn'
        }
        
        # Statistiken
        self.stats = {
            'total_records': 0,
            'parsed_records': 0,
            'field_counts': {},
            'field_quality': {}  # Neue Statistik für Datenqualität
        }
    
    def parse_content(self, content: str) -> pd.DataFrame:
        """Parst MAB2-Content und gibt DataFrame zurück"""
        # Teile Content in Records
        records = []
        raw_records = content.split('###')
        
        for raw_record in raw_records:
            if raw_record.strip():
                record = self._parse_record(raw_record)
                if record:
                    records.append(record)
                    
        # Erstelle DataFrame
        df = pd.DataFrame(records)
        
        # Nachbearbeitung der Felder
        df = self._post_process_fields(df)
        
        # Aktualisiere Statistiken
        self.stats['total_records'] = len(raw_records) - 1  # -1 wegen Split
        self.stats['parsed_records'] = len(records)
        self._update_field_quality_stats(df)
        
        return df
    
    def _clean_content(self, content: str) -> str:
        """Bereinigt Feldinhalt von MAB2-spezifischen Markierungen"""
        if not content:
            return ""
            
        # Entferne Subfeldmarkierungen
        content = re.sub(r'\$[a-z]', ' ', content)
        # Entferne Bearbeitungsklammern
        content = re.sub(r'¬\[.*?\]¬', '', content)
        # Bereinige spezielle Zeichen
        content = re.sub(r'[<>{}\\]', '', content)
        # Bereinige mehrfache Leerzeichen
        content = ' '.join(content.split())
        return content.strip()
    
    def _extract_year(self, year_str) -> Optional[str]:
        """Extrahiert das Jahr aus verschiedenen Formaten"""
        if pd.isna(year_str):
            return None
            
        # Konvertiere zu String wenn nötig
        year_str = str(year_str)
        
        # Verschiedene Jahr-Patterns
        patterns = [
            r'(\d{4})',           # Standard Jahr
            r'(\d{4})[\-\.]',     # Jahr mit Suffix
            r'©(\d{4})',          # Copyright Jahr
            r'\[(\d{4})\]'        # Jahr in Klammern
        ]
        
        for pattern in patterns:
            match = re.search(pattern, year_str)
            if match:
                year = match.group(1)
                # Validiere Jahr (1400-2100)
                if 1400 <= int(year) <= 2100:
                    return year
        return None
    
    def _clean_author(self, author) -> Optional[str]:
        """Bereinigt und normalisiert Autorennamen"""
        if pd.isna(author):
            return None
            
        # Konvertiere zu String wenn nötig
        author = str(author)
        if not author:
            return None
            
        # Entferne Rollenbezeichnungen
        author = re.sub(r'\[.*?\]', '', author)
        # Entferne Lebensdaten
        author = re.sub(r'\(.*?\)', '', author)
        # Entferne eckige Klammern und deren Inhalt (oft Funktionsbezeichnungen)
        author = re.sub(r'¬.*?¬', '', author)
        # Bereinige und normalisiere
        author = self._clean_content(author)
        return author if author else None
    
    def _clean_isbn(self, isbn) -> Optional[str]:
        """Bereinigt und validiert ISBN"""
        if pd.isna(isbn):
            return None
            
        # Konvertiere zu String wenn nötig
        isbn = str(isbn)
        if not isbn:
            return None
            
        # Extrahiere ISBN
        match = re.search(r'(?:ISBN[- ]*)?([\dX\-]+)', isbn)
        if match:
            # Entferne Bindestriche
            isbn = re.sub(r'[^\dX]', '', match.group(1))
            # Validiere Länge (ISBN-10 oder ISBN-13)
            if len(isbn) in [10, 13]:
                return isbn
        return None
    
    def _parse_record(self, raw_record: str) -> dict:
        """Parst einen einzelnen MAB2-Record"""
        record_data = {}
        
        # Verarbeite jede Zeile
        for line in raw_record.splitlines():
            line = line.strip()
            if not line:
                continue
            
            # Extrahiere Feldcode und Inhalt
            if len(line) >= 3 and line[:3].rstrip('abcdefghijklmnopqrstuvwxyz').isdigit():
                field_code = line[:3]
                content = line[3:].strip()
                
                # Extrahiere den eigentlichen Inhalt
                if content and content[0] in 'abcdefghijklmnopqrstuvwxyz':
                    content = content[1:]  # Entferne Subfeldkennung
                
                # Bereinige Inhalt
                content = self._clean_content(content)
                
                # Speichere Feld wenn es in key_fields ist
                if field_code in self.key_fields:
                    field_name = self.key_fields[field_code]
                    record_data[field_name] = content
                
                # Zähle Feldvorkommen für Statistik
                if field_code not in self.stats['field_counts']:
                    self.stats['field_counts'][field_code] = 0
                self.stats['field_counts'][field_code] += 1
        
        return record_data
    
    def _post_process_fields(self, df: pd.DataFrame) -> pd.DataFrame:
        """Nachbearbeitung der geparsten Felder"""
        # Jahr
        if 'year' in df.columns:
            df['year'] = df['year'].apply(self._extract_year)
            
        # ISBN
        if 'isbn' in df.columns:
            df['isbn'] = df['isbn'].apply(self._clean_isbn)
            
        # Autor
        if 'author' in df.columns:
            df['author'] = df['author'].apply(self._clean_author)
            
        # Titel
        if 'title' in df.columns:
            df['title'] = df['title'].apply(lambda x: self._clean_content(x) if pd.notna(x) else None)
            
        # Institution
        if 'institution' in df.columns:
            df['institution'] = df['institution'].apply(lambda x: self._clean_content(x) if pd.notna(x) else None)
            
        # Verlag
        if 'publisher' in df.columns:
            df['publisher'] = df['publisher'].apply(lambda x: self._clean_content(x) if pd.notna(x) else None)
            
        # Physische Beschreibung
        if 'physical_desc' in df.columns:
            df['physical_desc'] = df['physical_desc'].apply(lambda x: self._clean_content(x) if pd.notna(x) else None)
            
        return df
    
    def _update_field_quality_stats(self, df: pd.DataFrame) -> None:
        """Aktualisiert Statistiken zur Datenqualität"""
        total_records = len(df)
        self.stats['field_quality'] = {}
        
        for col in df.columns:
            non_null = df[col].count()
            quality = {
                'vorhanden': non_null,
                'fehlend': total_records - non_null,
                'abdeckung': f"{(non_null/total_records*100):.1f}%"
            }
            if non_null > 0:
                unique = df[col].nunique()
                quality['eindeutige_werte'] = unique
                quality['eindeutigkeit'] = f"{(unique/non_null*100):.1f}%"
            
            self.stats['field_quality'][col] = quality
    
    def get_stats(self) -> dict:
        """Gibt erweiterte Parsing-Statistiken zurück"""
        stats = {
            'Gesamtrecords': self.stats['total_records'],
            'Erfolgreich geparst': self.stats['parsed_records'],
            'Erfolgsrate': f"{(self.stats['parsed_records']/max(1, self.stats['total_records'])*100):.1f}%",
            'Top 10 Felder': dict(sorted(
                self.stats['field_counts'].items(), 
                key=lambda x: x[1], 
                reverse=True
            )[:10]),
            'Datenqualität': self.stats['field_quality']
        }
        return stats

# Erstelle Parser-Instanz
parser = SimpleMab2Parser()

# Parse Beispieldaten
print("🔍 Parse MAB2 Beispieldaten...")
df = parser.parse_content(content)

# Zeige Ergebnisse
print(f"\n✅ Parsing abgeschlossen!")
print(f"📊 Records im DataFrame: {len(df)}")

print("\n📋 Spalten im DataFrame:")
for col in df.columns:
    non_null = df[col].count()
    pct = non_null/len(df)*100
    print(f"   {col:15}: {non_null:3d} Werte ({pct:6.1f}%)")

print("\n📈 Parser Statistiken:")
stats = parser.get_stats()
for key, value in stats.items():
    print(f"\n   {key}:")
    if isinstance(value, dict):
        if key == 'Datenqualität':
            for field, quality in value.items():
                print(f"\n      {field}:")
                for metric, val in quality.items():
                    print(f"         {metric}: {val}")
        else:
            for k, v in value.items():
                print(f"      {k}: {v}")
    else:
        print(f"      {value}")

print("\n🔍 Beispiel-Records:")
print("\nErster Record:")
print(df.iloc[0].to_string())
print("\nZweiter Record:")
print(df.iloc[1].to_string())
# Out:
# 🔍 Parse MAB2 Beispieldaten...
#
# ✅ Parsing abgeschlossen!
# 📊 Records im DataFrame: 4
#
# 📋 Spalten im DataFrame:
#    id             :   4 Werte ( 100.0%)
#    institution    :   4 Werte ( 100.0%)
#    title          :   4 Werte ( 100.0%)
#    place          :   4 Werte ( 100.0%)
#    physical_desc  :   3 Werte (  75.0%)
#    author         :   1 Werte (  25.0%)
#    year           :   3 Werte (  75.0%)
#    publisher      :   2 Werte (  50.0%)
#    isbn           :   2 Werte (  50.0%)
#
# 📈 Parser Statistiken:
#
#    Gesamtrecords:
#       4
#
#    Erfolgreich geparst:
#       4
#
#    Erfolgsrate:
#       100.0%
#
#    Top 10 Felder:
#       026: 8
#       425: 6
#       076: 5
#       001: 4
#       002: 4
#       003: 4
#       030: 4
#       050: 4
#       051: 4
#       060: 4
#
#    Datenqualität:
#
#       id:
#          vorhanden: 4
#          fehlend: 0
#          abdeckung: 100.0%
#          eindeutige_werte: 4
#          eindeutigkeit: 100.0%
#
#       institution:
#          vorhanden: 4
#          fehlend: 0
#          abdeckung: 100.0%
#          eindeutige_werte: 2
#          eindeutigkeit: 50.0%
#
#       title:
#          vorhanden: 4
#          fehlend: 0
#          abdeckung: 100.0%
#          eindeutige_werte: 4
#          eindeutigkeit: 100.0%
#
#       place:
#          vorhanden: 4
#          fehlend: 0
#          abdeckung: 100.0%
#          eindeutige_werte: 2
#          eindeutigkeit: 50.0%
#
#       physical_desc:
#          vorhanden: 3
#          fehlend: 1
#          abdeckung: 75.0%
#          eindeutige_werte: 3
#          eindeutigkeit: 100.0%
#
#       author:
#          vorhanden: 1
#          fehlend: 3
#          abdeckung: 25.0%
#          eindeutige_werte: 1
#          eindeutigkeit: 100.0%
#
#       year:
#          vorhanden: 3
#          fehlend: 1
#          abdeckung: 75.0%
#          eindeutige_werte: 3
#          eindeutigkeit: 100.0%
#
#       publisher:
#          vorhanden: 2
#          fehlend: 2
#          abdeckung: 50.0%
#          eindeutige_werte: 1
#          eindeutigkeit: 50.0%
#
#       isbn:
#          vorhanden: 2
#          fehlend: 2
#          abdeckung: 50.0%
#          eindeutige_werte: 2
#          eindeutigkeit: 100.0%
#
# 🔍 Beispiel-Records:
#
# Erster Record:
# id                                     073871532
# institution      Bayern / Geologisches Landesamt
# title               Geologische Karte von Bayern
# place                                    München
# physical_desc              Je Bl. 47,5 x 44,5 cm
# author                                      None
# year                                        None
# publisher                                   None
# isbn                                        None
#
# Zweiter Record:
# id                                    9073875056
# institution      Bayern / Geologisches Landesamt
# title                                    [Karte]
# place                                    München
# physical_desc                               1 Kt
# author                        Kuhnert, Christian
# year                                        1967
# publisher                                   None
# isbn                                        None

# %% [markdown]
# # 📚 MAB2 Parser Details
#
# Der neue Parser wurde gezielt für die MAB2-Daten der UB TUBAF entwickelt und fokussiert sich auf die wichtigsten bibliographischen Felder.
#
# ## 🎯 Funktionsweise
#
# 1. **Record-Trennung**:
#    - Datensätze werden durch `###` getrennt
#    - Jeder Record enthält mehrere Felder mit 3-stelligen Codes
#
# 2. **Feldverarbeitung**:
#    - Codes wie `001`, `331`, `425` identifizieren Felder
#    - Subfelder (z.B. `$a`, `$b`) werden automatisch bereinigt
#    - Spezielle Kennungen werden normalisiert
#
# 3. **Extraktion wichtiger Felder**:
#    - `001`: Identifikationsnummer
#    - `100`: Autor
#    - `200`: Institution/Körperschaft
#    - `331`: Titel
#    - `425`: Erscheinungsjahr
#    - `410`: Erscheinungsort
#    - `412`: Verlag
#    - `433`: Physische Beschreibung
#    - `540`: ISBN
#
# ## 📊 Statistiken
# - Anzahl verarbeiteter Records
# - Erfolgsrate des Parsings
# - Häufigkeit der einzelnen Felder

# %%
# 🧪 MAB2 Parser Testen

# Importiere den verbesserten Parser
from parsers.mab2_parser import MAB2Parser, analyze_mab2_data, get_sample_records_mab2
import logging

# Logging konfigurieren
logging.basicConfig(level=logging.INFO, format='%(message)s')

# 1️⃣ Test mit Beispieldaten
print("🔍 TESTE BEISPIELDATEN")
print("-" * 50)

# Lese die Beispieldaten als Datei ein
import tempfile
from pathlib import Path

# Erstelle temporäre Datei mit den Beispieldaten
with tempfile.NamedTemporaryFile(mode='w', suffix='.dat', encoding='latin1', delete=False) as temp:
    temp.write(content)
    temp_path = Path(temp.name)

try:
    # Parse die temporäre Datei
    parser = MAB2Parser(encoding='latin1')
    df_example = parser.parse_file(temp_path)

    print("\n📊 Analyse der Beispieldaten:")
    analyze_mab2_data(df_example)

    # 2️⃣ Test mit vollständigem Datenbestand
    print("\n\n🔍 TESTE GESAMTEN DATENBESTAND")
    print("-" * 50)

    # Lade MAB2-Datei aus der Konfiguration
    data_file = config.get_path('data.ub_tubaf.raw') / '027out.t'
    
    if not data_file.exists():
        print(f"❌ Datei nicht gefunden: {data_file}")
    else:
        print(f"📂 Verarbeite Datei: {data_file}")
        print(f"📊 Encoding: {ub_config.get('encoding', 'latin1')}")
        
        # Parse Daten
        parser = MAB2Parser(encoding=ub_config.get('encoding', 'latin1'))
        df_full = parser.parse_file(data_file)
        
        print("\n📊 Analyse des Gesamtdatenbestands:")
        analyze_mab2_data(df_full)
        
        # Zeige Beispielrecords
        print("\n🔍 Beispiel-Records aus dem Gesamtdatenbestand:")
        sample_df = get_sample_records_mab2(df_full, n=3)
        print(sample_df.to_string())
        
except Exception as e:
    print(f"❌ Fehler beim Verarbeiten der Daten: {str(e)}")
finally:
    # Lösche die temporäre Datei
    if 'temp_path' in locals():
        temp_path.unlink()
# Out:
# 🔄 Lade MAB2-Datei: /tmp/tmpkyoepxa9.dat
# 📊 Encoding: latin1
# 📋 Gefundene Records: 4
#
# ✅ ERFOLGREICH GEPARST (Record 1):
# 📊 Encoding: latin1
# 📋 Gefundene Records: 4
#
# ✅ ERFOLGREICH GEPARST (Record 1):
#    id: 00499
#    source: ub_tubaf_mab2
#    title: Geologische Karte von Bayern <1:25000> : Geologische Karte von Bayern
#    authors: ['Bayern / Geologisches Landesamt']
#    authors_str: Bayern / Geologisches Landesamt
#    year: None
#    isbn: None
#    place: München
#    physical_desc: Je Bl. 47,5 x 44,5 cm
#    id: 00499
#    source: ub_tubaf_mab2
#    title: Geologische Karte von Bayern <1:25000> : Geologische Karte von Bayern
#    authors: ['Bayern / Geologisches Landesamt']
#    authors_str: Bayern / Geologisches Landesamt
#    year: None
#    isbn: None
#    place: München
#    physical_desc: Je Bl. 47,5 x 44,5 cm
#    title_candidates: ['Geologische Karte von Bayern <1:25000>', 'Geologische Karte von Bayern', 'hrsg. vom Bayerischen Geologischen Landesamt']
# ❌ Fehler beim Parsen von Record 2:
#    expected string or bytes-like object, got 'list'
#    Record-Start: ### 00599nM2.01200024      u
# 001 9073875056
# 002a20020501
# 003 20230321140005
# 010 073871532
# 013k073871...
# ❌ Fehler beim Parsen von Record 3:
#    expected string or bytes-like object, got 'list'
#    Record-Start: ### 00481nM2.01200024      h
# 001 9125700332
# 002a19930613
# 003 20230519125958
# 026k125700334
# 026 GBV125...
# ❌ Fehler beim Parsen von Record 4:
#    expected string or bytes-like object, got 'list'
#    Record-Start: ### 00718nM2.01200024      u
# 001 9162859218
# 002a19940909
# 003 20230519130014
# 010 9125700332
# 013k12570...
#
# ✅ MAB2-Parsing abgeschlossen:
#    📋 Total Records: 4
#    ✅ Erfolgreich geparst: 1
#    ❌ Fehler: 3
#    📊 DataFrame: 1 Zeilen, 11 Spalten
#
# 📊 === MAB2 DATENANALYSE ===
# 📋 Datensatz: 1 Records
#
# 🔍 === VOLLSTÄNDIGKEITS-ANALYSE ===
# 📖 Records mit Titel: 1 (100.0%)
# ✍️  Records mit Autor: 1 (100.0%)
# 📅 Records mit Jahr: 0 (0.0%)
# 📚 Records mit ISBN: 0 (0.0%)
#    title_candidates: ['Geologische Karte von Bayern <1:25000>', 'Geologische Karte von Bayern', 'hrsg. vom Bayerischen Geologischen Landesamt']
# ❌ Fehler beim Parsen von Record 2:
#    expected string or bytes-like object, got 'list'
#    Record-Start: ### 00599nM2.01200024      u
# 001 9073875056
# 002a20020501
# 003 20230321140005
# 010 073871532
# 013k073871...
# ❌ Fehler beim Parsen von Record 3:
#    expected string or bytes-like object, got 'list'
#    Record-Start: ### 00481nM2.01200024      h
# 001 9125700332
# 002a19930613
# 003 20230519125958
# 026k125700334
# 026 GBV125...
# ❌ Fehler beim Parsen von Record 4:
#    expected string or bytes-like object, got 'list'
#    Record-Start: ### 00718nM2.01200024      u
# 001 9162859218
# 002a19940909
# 003 20230519130014
# 010 9125700332
# 013k12570...
#
# ✅ MAB2-Parsing abgeschlossen:
#    📋 Total Records: 4
#    ✅ Erfolgreich geparst: 1
#    ❌ Fehler: 3
#    📊 DataFrame: 1 Zeilen, 11 Spalten
#
# 📊 === MAB2 DATENANALYSE ===
# 📋 Datensatz: 1 Records
#
# 🔍 === VOLLSTÄNDIGKEITS-ANALYSE ===
# 📖 Records mit Titel: 1 (100.0%)
# ✍️  Records mit Autor: 1 (100.0%)
# 📅 Records mit Jahr: 0 (0.0%)
# 📚 Records mit ISBN: 0 (0.0%)
#
# ✍️  === TOP 5 AUTOREN ===
#    Bayern / Geologisches Landesamt: 1 Records
# 🔄 Lade MAB2-Datei: /media/sz/Data/Bibo/analysis/data/ub_tubaf/raw/027out.t
# 📊 Encoding: latin1
#
# ✍️  === TOP 5 AUTOREN ===
#    Bayern / Geologisches Landesamt: 1 Records
# 🔄 Lade MAB2-Datei: /media/sz/Data/Bibo/analysis/data/ub_tubaf/raw/027out.t
# 📊 Encoding: latin1
# 🔍 TESTE BEISPIELDATEN
# --------------------------------------------------
#
# 📊 Analyse der Beispieldaten:
#
#
# 🔍 TESTE GESAMTEN DATENBESTAND
# --------------------------------------------------
# 📂 Verarbeite Datei: /media/sz/Data/Bibo/analysis/data/ub_tubaf/raw/027out.t
# 📊 Encoding: latin1
# 📋 Gefundene Records: 518,954
#
# ✅ ERFOLGREICH GEPARST (Record 1):
#    id: 00499
#    source: ub_tubaf_mab2
#    title: Geologische Karte von Bayern <1:25000> : Geologische Karte von Bayern
#    authors: ['Bayern / Geologisches Landesamt']
#    authors_str: Bayern / Geologisches Landesamt
#    year: None
#    isbn: None
#    place: München
#    physical_desc: Je Bl. 47,5 x 44,5 cm
#    title_candidates: ['Geologische Karte von Bayern <1:25000>', 'Geologische Karte von Bayern', 'hrsg. vom Bayerischen Geologischen Landesamt']
# ❌ Fehler beim Parsen von Record 2:
#    expected string or bytes-like object, got 'list'
#    Record-Start: ### 00599nM2.01200024      u
# 001 9073875056
# 002a20020501
# 003 20230321140005
# 010 073871532
# 013k073871...
# ❌ Fehler beim Parsen von Record 3:
#    expected string or bytes-like object, got 'list'
#    Record-Start: ### 00481nM2.01200024      h
# 001 9125700332
# 002a19930613
# 003 20230519125958
# 026k125700334
# 026 GBV125...
# ❌ Fehler beim Parsen von Record 4:
#    expected string or bytes-like object, got 'list'
#    Record-Start: ### 00718nM2.01200024      u
# 001 9162859218
# 002a19940909
# 003 20230519130014
# 010 9125700332
# 013k12570...
# ❌ Fehler beim Parsen von Record 5:
#    expected string or bytes-like object, got 'list'
#
# ✅ ERFOLGREICH GEPARST (Record 1):
#    id: 00499
#    source: ub_tubaf_mab2
#    title: Geologische Karte von Bayern <1:25000> : Geologische Karte von Bayern
#    authors: ['Bayern / Geologisches Landesamt']
#    authors_str: Bayern / Geologisches Landesamt
#    year: None
#    isbn: None
#    place: München
#    physical_desc: Je Bl. 47,5 x 44,5 cm
#    title_candidates: ['Geologische Karte von Bayern <1:25000>', 'Geologische Karte von Bayern', 'hrsg. vom Bayerischen Geologischen Landesamt']
# ❌ Fehler beim Parsen von Record 2:
#    expected string or bytes-like object, got 'list'
#    Record-Start: ### 00599nM2.01200024      u
# 001 9073875056
# 002a20020501
# 003 20230321140005
# 010 073871532
# 013k073871...
# ❌ Fehler beim Parsen von Record 3:
#    expected string or bytes-like object, got 'list'
#    Record-Start: ### 00481nM2.01200024      h
# 001 9125700332
# 002a19930613
# 003 20230519125958
# 026k125700334
# 026 GBV125...
# ❌ Fehler beim Parsen von Record 4:
#    expected string or bytes-like object, got 'list'
#    Record-Start: ### 00718nM2.01200024      u
# 001 9162859218
# 002a19940909
# 003 20230519130014
# 010 9125700332
# 013k12570...
# ❌ Fehler beim Parsen von Record 5:
#    expected string or bytes-like object, got 'list'
#    Record-Start: ### 01593nM2.01200024      h
# 001 014392623
# 002a19931114
# 003 20230925153328
# 025a01000419X
# 025 OCoLC23...
#    Record-Start: ### 01593nM2.01200024      h
# 001 014392623
# 002a19931114
# 003 20230925153328
# 025a01000419X
# 025 OCoLC23...
# 📊 Verarbeitet: 1,000 Records (Erfolgsrate: 27.5%)
# 📊 Verarbeitet: 1,000 Records (Erfolgsrate: 27.5%)
# 📊 Verarbeitet: 2,000 Records (Erfolgsrate: 18.6%)
# 📊 Verarbeitet: 2,000 Records (Erfolgsrate: 18.6%)
# 📊 Verarbeitet: 3,000 Records (Erfolgsrate: 13.0%)
# 📊 Verarbeitet: 3,000 Records (Erfolgsrate: 13.0%)
# 📊 Verarbeitet: 4,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 4,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 5,000 Records (Erfolgsrate: 8.5%)
# 📊 Verarbeitet: 5,000 Records (Erfolgsrate: 8.5%)
# 📊 Verarbeitet: 6,000 Records (Erfolgsrate: 7.3%)
# 📊 Verarbeitet: 6,000 Records (Erfolgsrate: 7.3%)
# 📊 Verarbeitet: 7,000 Records (Erfolgsrate: 6.5%)
# 📊 Verarbeitet: 7,000 Records (Erfolgsrate: 6.5%)
# 📊 Verarbeitet: 8,000 Records (Erfolgsrate: 6.0%)
# 📊 Verarbeitet: 8,000 Records (Erfolgsrate: 6.0%)
# 📊 Verarbeitet: 9,000 Records (Erfolgsrate: 5.4%)
# 📊 Verarbeitet: 9,000 Records (Erfolgsrate: 5.4%)
# 📊 Verarbeitet: 10,000 Records (Erfolgsrate: 5.0%)
# 📊 Verarbeitet: 10,000 Records (Erfolgsrate: 5.0%)
# 📊 Verarbeitet: 11,000 Records (Erfolgsrate: 4.6%)
# 📊 Verarbeitet: 11,000 Records (Erfolgsrate: 4.6%)
# 📊 Verarbeitet: 12,000 Records (Erfolgsrate: 4.4%)
# 📊 Verarbeitet: 12,000 Records (Erfolgsrate: 4.4%)
# 📊 Verarbeitet: 13,000 Records (Erfolgsrate: 4.2%)
# 📊 Verarbeitet: 13,000 Records (Erfolgsrate: 4.2%)
# 📊 Verarbeitet: 14,000 Records (Erfolgsrate: 3.9%)
# 📊 Verarbeitet: 14,000 Records (Erfolgsrate: 3.9%)
# 📊 Verarbeitet: 15,000 Records (Erfolgsrate: 3.9%)
# 📊 Verarbeitet: 15,000 Records (Erfolgsrate: 3.9%)
# 📊 Verarbeitet: 16,000 Records (Erfolgsrate: 3.7%)
# 📊 Verarbeitet: 16,000 Records (Erfolgsrate: 3.7%)
# 📊 Verarbeitet: 17,000 Records (Erfolgsrate: 3.6%)
# 📊 Verarbeitet: 17,000 Records (Erfolgsrate: 3.6%)
# 📊 Verarbeitet: 18,000 Records (Erfolgsrate: 3.5%)
# 📊 Verarbeitet: 18,000 Records (Erfolgsrate: 3.5%)
# 📊 Verarbeitet: 19,000 Records (Erfolgsrate: 3.3%)
# 📊 Verarbeitet: 19,000 Records (Erfolgsrate: 3.3%)
# 📊 Verarbeitet: 20,000 Records (Erfolgsrate: 3.2%)
# 📊 Verarbeitet: 20,000 Records (Erfolgsrate: 3.2%)
# 📊 Verarbeitet: 21,000 Records (Erfolgsrate: 3.1%)
# 📊 Verarbeitet: 21,000 Records (Erfolgsrate: 3.1%)
# 📊 Verarbeitet: 22,000 Records (Erfolgsrate: 3.0%)
# 📊 Verarbeitet: 22,000 Records (Erfolgsrate: 3.0%)
# 📊 Verarbeitet: 23,000 Records (Erfolgsrate: 2.9%)
# 📊 Verarbeitet: 23,000 Records (Erfolgsrate: 2.9%)
# 📊 Verarbeitet: 24,000 Records (Erfolgsrate: 2.8%)
# 📊 Verarbeitet: 24,000 Records (Erfolgsrate: 2.8%)
# ⚠️  Record ohne Kernfelder: ID=00293
# ⚠️  Record ohne Kernfelder: ID=00293
# 📊 Verarbeitet: 25,000 Records (Erfolgsrate: 2.8%)
# 📊 Verarbeitet: 25,000 Records (Erfolgsrate: 2.8%)
# 📊 Verarbeitet: 26,000 Records (Erfolgsrate: 2.7%)
# 📊 Verarbeitet: 26,000 Records (Erfolgsrate: 2.7%)
# 📊 Verarbeitet: 27,000 Records (Erfolgsrate: 2.7%)
# 📊 Verarbeitet: 27,000 Records (Erfolgsrate: 2.7%)
# 📊 Verarbeitet: 28,000 Records (Erfolgsrate: 2.6%)
# 📊 Verarbeitet: 28,000 Records (Erfolgsrate: 2.6%)
# 📊 Verarbeitet: 29,000 Records (Erfolgsrate: 2.5%)
# 📊 Verarbeitet: 29,000 Records (Erfolgsrate: 2.5%)
# ⚠️  Record ohne Kernfelder: ID=00408
# ⚠️  Record ohne Kernfelder: ID=00408
# 📊 Verarbeitet: 30,000 Records (Erfolgsrate: 2.4%)
# 📊 Verarbeitet: 30,000 Records (Erfolgsrate: 2.4%)
# 📊 Verarbeitet: 31,000 Records (Erfolgsrate: 2.4%)
# 📊 Verarbeitet: 31,000 Records (Erfolgsrate: 2.4%)
# 📊 Verarbeitet: 32,000 Records (Erfolgsrate: 2.3%)
# 📊 Verarbeitet: 32,000 Records (Erfolgsrate: 2.3%)
# 📊 Verarbeitet: 33,000 Records (Erfolgsrate: 2.3%)
# 📊 Verarbeitet: 33,000 Records (Erfolgsrate: 2.3%)
# 📊 Verarbeitet: 34,000 Records (Erfolgsrate: 2.2%)
# 📊 Verarbeitet: 34,000 Records (Erfolgsrate: 2.2%)
# 📊 Verarbeitet: 35,000 Records (Erfolgsrate: 2.2%)
# 📊 Verarbeitet: 35,000 Records (Erfolgsrate: 2.2%)
# 📊 Verarbeitet: 36,000 Records (Erfolgsrate: 2.5%)
# 📊 Verarbeitet: 36,000 Records (Erfolgsrate: 2.5%)
# 📊 Verarbeitet: 37,000 Records (Erfolgsrate: 2.4%)
# 📊 Verarbeitet: 37,000 Records (Erfolgsrate: 2.4%)
# 📊 Verarbeitet: 38,000 Records (Erfolgsrate: 2.4%)
# 📊 Verarbeitet: 38,000 Records (Erfolgsrate: 2.4%)
# 📊 Verarbeitet: 39,000 Records (Erfolgsrate: 2.3%)
# 📊 Verarbeitet: 39,000 Records (Erfolgsrate: 2.3%)
# 📊 Verarbeitet: 40,000 Records (Erfolgsrate: 2.3%)
# 📊 Verarbeitet: 40,000 Records (Erfolgsrate: 2.3%)
# 📊 Verarbeitet: 41,000 Records (Erfolgsrate: 2.2%)
# 📊 Verarbeitet: 41,000 Records (Erfolgsrate: 2.2%)
# 📊 Verarbeitet: 42,000 Records (Erfolgsrate: 2.2%)
# 📊 Verarbeitet: 42,000 Records (Erfolgsrate: 2.2%)
# 📊 Verarbeitet: 43,000 Records (Erfolgsrate: 2.2%)
# 📊 Verarbeitet: 43,000 Records (Erfolgsrate: 2.2%)
# 📊 Verarbeitet: 44,000 Records (Erfolgsrate: 2.2%)
# 📊 Verarbeitet: 44,000 Records (Erfolgsrate: 2.2%)
# 📊 Verarbeitet: 45,000 Records (Erfolgsrate: 2.2%)
# 📊 Verarbeitet: 45,000 Records (Erfolgsrate: 2.2%)
# 📊 Verarbeitet: 46,000 Records (Erfolgsrate: 2.2%)
# 📊 Verarbeitet: 46,000 Records (Erfolgsrate: 2.2%)
# 📊 Verarbeitet: 47,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 47,000 Records (Erfolgsrate: 2.1%)
# ⚠️  Record ohne Kernfelder: ID=00757
# ⚠️  Record ohne Kernfelder: ID=00757
# 📊 Verarbeitet: 48,000 Records (Erfolgsrate: 2.1%)
# ⚠️  Record ohne Kernfelder: ID=00754
# ⚠️  Record ohne Kernfelder: ID=00757
# ⚠️  Record ohne Kernfelder: ID=00757
# 📊 Verarbeitet: 48,000 Records (Erfolgsrate: 2.1%)
# ⚠️  Record ohne Kernfelder: ID=00754
# ⚠️  Record ohne Kernfelder: ID=00337
# ⚠️  Record ohne Kernfelder: ID=00337
# 📊 Verarbeitet: 49,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 49,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 50,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 50,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 51,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 51,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 52,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 52,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 53,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 53,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 54,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 54,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 55,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 55,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 56,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 56,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 57,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 57,000 Records (Erfolgsrate: 2.1%)
# 📊 Verarbeitet: 58,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 58,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 59,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 59,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 60,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 60,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 61,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 61,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 62,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 62,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 63,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 63,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 64,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 64,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 65,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 65,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 66,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 66,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 67,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 67,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 68,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 68,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 69,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 69,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 70,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 70,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 71,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 71,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 72,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 72,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 73,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 73,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 74,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 74,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 75,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 75,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 76,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 76,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 77,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 77,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 78,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 78,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 79,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 79,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 80,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 80,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 81,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 81,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 82,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 82,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 83,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 83,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 84,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 84,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 85,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 85,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 86,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 86,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 87,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 87,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 88,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 88,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 89,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 89,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 90,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 90,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 91,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 91,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 92,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 92,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 93,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 93,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 94,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 94,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 95,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 95,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 96,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 96,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 97,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 97,000 Records (Erfolgsrate: 1.9%)
# 📊 Verarbeitet: 98,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 98,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 99,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 99,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 100,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 100,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 101,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 101,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 102,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 102,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 103,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 103,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 104,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 104,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 105,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 105,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 106,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 106,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 107,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 107,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 108,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 108,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 109,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 109,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 110,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 110,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 111,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 111,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 112,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 112,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 113,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 113,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 114,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 114,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 115,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 115,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 116,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 116,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 117,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 117,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 118,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 118,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 119,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 119,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 120,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 120,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 121,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 121,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 122,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 122,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 123,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 123,000 Records (Erfolgsrate: 1.7%)
# 📊 Verarbeitet: 124,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 124,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 125,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 125,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 126,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 126,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 127,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 127,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 128,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 128,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 129,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 129,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 130,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 130,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 131,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 131,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 132,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 132,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 133,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 133,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 134,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 134,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 135,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 135,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 136,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 136,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 137,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 137,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 138,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 138,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 139,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 139,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 140,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 140,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 141,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 141,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 142,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 142,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 143,000 Records (Erfolgsrate: 1.5%)
# 📊 Verarbeitet: 143,000 Records (Erfolgsrate: 1.5%)
# 📊 Verarbeitet: 144,000 Records (Erfolgsrate: 1.5%)
# 📊 Verarbeitet: 144,000 Records (Erfolgsrate: 1.5%)
# 📊 Verarbeitet: 145,000 Records (Erfolgsrate: 1.5%)
# 📊 Verarbeitet: 145,000 Records (Erfolgsrate: 1.5%)
# 📊 Verarbeitet: 146,000 Records (Erfolgsrate: 1.5%)
# 📊 Verarbeitet: 146,000 Records (Erfolgsrate: 1.5%)
# 📊 Verarbeitet: 147,000 Records (Erfolgsrate: 1.5%)
# 📊 Verarbeitet: 147,000 Records (Erfolgsrate: 1.5%)
# 📊 Verarbeitet: 148,000 Records (Erfolgsrate: 1.5%)
# 📊 Verarbeitet: 148,000 Records (Erfolgsrate: 1.5%)
# 📊 Verarbeitet: 149,000 Records (Erfolgsrate: 1.5%)
# 📊 Verarbeitet: 149,000 Records (Erfolgsrate: 1.5%)
# 📊 Verarbeitet: 150,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 150,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 151,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 151,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 152,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 152,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 153,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 153,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 154,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 154,000 Records (Erfolgsrate: 1.6%)
# 📊 Verarbeitet: 155,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 155,000 Records (Erfolgsrate: 1.8%)
# 📊 Verarbeitet: 156,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 156,000 Records (Erfolgsrate: 2.0%)
# 📊 Verarbeitet: 157,000 Records (Erfolgsrate: 2.4%)
# 📊 Verarbeitet: 157,000 Records (Erfolgsrate: 2.4%)
# 📊 Verarbeitet: 158,000 Records (Erfolgsrate: 2.7%)
# 📊 Verarbeitet: 158,000 Records (Erfolgsrate: 2.7%)
# 📊 Verarbeitet: 159,000 Records (Erfolgsrate: 3.0%)
# 📊 Verarbeitet: 159,000 Records (Erfolgsrate: 3.0%)
# 📊 Verarbeitet: 160,000 Records (Erfolgsrate: 3.2%)
# 📊 Verarbeitet: 160,000 Records (Erfolgsrate: 3.2%)
# 📊 Verarbeitet: 161,000 Records (Erfolgsrate: 3.5%)
# 📊 Verarbeitet: 161,000 Records (Erfolgsrate: 3.5%)
# 📊 Verarbeitet: 162,000 Records (Erfolgsrate: 4.0%)
# 📊 Verarbeitet: 162,000 Records (Erfolgsrate: 4.0%)
# 📊 Verarbeitet: 163,000 Records (Erfolgsrate: 4.5%)
# 📊 Verarbeitet: 163,000 Records (Erfolgsrate: 4.5%)
# 📊 Verarbeitet: 164,000 Records (Erfolgsrate: 4.9%)
# 📊 Verarbeitet: 164,000 Records (Erfolgsrate: 4.9%)
# 📊 Verarbeitet: 165,000 Records (Erfolgsrate: 5.4%)
# 📊 Verarbeitet: 165,000 Records (Erfolgsrate: 5.4%)
# 📊 Verarbeitet: 166,000 Records (Erfolgsrate: 5.8%)
# 📊 Verarbeitet: 166,000 Records (Erfolgsrate: 5.8%)
# 📊 Verarbeitet: 167,000 Records (Erfolgsrate: 5.7%)
# 📊 Verarbeitet: 167,000 Records (Erfolgsrate: 5.7%)
# 📊 Verarbeitet: 168,000 Records (Erfolgsrate: 5.7%)
# 📊 Verarbeitet: 168,000 Records (Erfolgsrate: 5.7%)
# 📊 Verarbeitet: 169,000 Records (Erfolgsrate: 5.7%)
# 📊 Verarbeitet: 169,000 Records (Erfolgsrate: 5.7%)
# 📊 Verarbeitet: 170,000 Records (Erfolgsrate: 5.7%)
# 📊 Verarbeitet: 170,000 Records (Erfolgsrate: 5.7%)
# 📊 Verarbeitet: 171,000 Records (Erfolgsrate: 5.8%)
# 📊 Verarbeitet: 171,000 Records (Erfolgsrate: 5.8%)
# 📊 Verarbeitet: 172,000 Records (Erfolgsrate: 5.8%)
# 📊 Verarbeitet: 172,000 Records (Erfolgsrate: 5.8%)
# 📊 Verarbeitet: 173,000 Records (Erfolgsrate: 5.8%)
# 📊 Verarbeitet: 173,000 Records (Erfolgsrate: 5.8%)
# 📊 Verarbeitet: 174,000 Records (Erfolgsrate: 5.8%)
# 📊 Verarbeitet: 174,000 Records (Erfolgsrate: 5.8%)
# 📊 Verarbeitet: 175,000 Records (Erfolgsrate: 5.8%)
# 📊 Verarbeitet: 175,000 Records (Erfolgsrate: 5.8%)
# 📊 Verarbeitet: 176,000 Records (Erfolgsrate: 5.8%)
# 📊 Verarbeitet: 176,000 Records (Erfolgsrate: 5.8%)
# ⚠️  Record ohne Kernfelder: ID=00404
# ⚠️  Record ohne Kernfelder: ID=00404
# 📊 Verarbeitet: 177,000 Records (Erfolgsrate: 5.8%)
# 📊 Verarbeitet: 177,000 Records (Erfolgsrate: 5.8%)
# 📊 Verarbeitet: 178,000 Records (Erfolgsrate: 5.8%)
# 📊 Verarbeitet: 178,000 Records (Erfolgsrate: 5.8%)
# 📊 Verarbeitet: 179,000 Records (Erfolgsrate: 5.8%)
# ⚠️  Record ohne Kernfelder: ID=00351
# ⚠️  Record ohne Kernfelder: ID=00351
# 📊 Verarbeitet: 179,000 Records (Erfolgsrate: 5.8%)
# ⚠️  Record ohne Kernfelder: ID=00351
# ⚠️  Record ohne Kernfelder: ID=00351
# ⚠️  Record ohne Kernfelder: ID=00351
# ⚠️  Record ohne Kernfelder: ID=00351
# 📊 Verarbeitet: 180,000 Records (Erfolgsrate: 5.9%)
# 📊 Verarbeitet: 180,000 Records (Erfolgsrate: 5.9%)
# 📊 Verarbeitet: 181,000 Records (Erfolgsrate: 5.9%)
# 📊 Verarbeitet: 181,000 Records (Erfolgsrate: 5.9%)
# 📊 Verarbeitet: 182,000 Records (Erfolgsrate: 5.9%)
# 📊 Verarbeitet: 182,000 Records (Erfolgsrate: 5.9%)
# 📊 Verarbeitet: 183,000 Records (Erfolgsrate: 5.9%)
# 📊 Verarbeitet: 183,000 Records (Erfolgsrate: 5.9%)
# 📊 Verarbeitet: 184,000 Records (Erfolgsrate: 6.0%)
# 📊 Verarbeitet: 184,000 Records (Erfolgsrate: 6.0%)
# 📊 Verarbeitet: 185,000 Records (Erfolgsrate: 6.0%)
# 📊 Verarbeitet: 185,000 Records (Erfolgsrate: 6.0%)
# 📊 Verarbeitet: 186,000 Records (Erfolgsrate: 6.0%)
# 📊 Verarbeitet: 186,000 Records (Erfolgsrate: 6.0%)
# 📊 Verarbeitet: 187,000 Records (Erfolgsrate: 6.0%)
# 📊 Verarbeitet: 187,000 Records (Erfolgsrate: 6.0%)
# 📊 Verarbeitet: 188,000 Records (Erfolgsrate: 6.1%)
# 📊 Verarbeitet: 188,000 Records (Erfolgsrate: 6.1%)
# 📊 Verarbeitet: 189,000 Records (Erfolgsrate: 6.1%)
# 📊 Verarbeitet: 189,000 Records (Erfolgsrate: 6.1%)
# 📊 Verarbeitet: 190,000 Records (Erfolgsrate: 6.1%)
# 📊 Verarbeitet: 190,000 Records (Erfolgsrate: 6.1%)
# 📊 Verarbeitet: 191,000 Records (Erfolgsrate: 6.2%)
# ⚠️  Record ohne Kernfelder: ID=00556
# 📊 Verarbeitet: 191,000 Records (Erfolgsrate: 6.2%)
# ⚠️  Record ohne Kernfelder: ID=00556
# 📊 Verarbeitet: 192,000 Records (Erfolgsrate: 6.2%)
# 📊 Verarbeitet: 192,000 Records (Erfolgsrate: 6.2%)
# 📊 Verarbeitet: 193,000 Records (Erfolgsrate: 6.3%)
# 📊 Verarbeitet: 193,000 Records (Erfolgsrate: 6.3%)
# 📊 Verarbeitet: 194,000 Records (Erfolgsrate: 6.3%)
# 📊 Verarbeitet: 194,000 Records (Erfolgsrate: 6.3%)
# 📊 Verarbeitet: 195,000 Records (Erfolgsrate: 6.3%)
# 📊 Verarbeitet: 195,000 Records (Erfolgsrate: 6.3%)
# 📊 Verarbeitet: 196,000 Records (Erfolgsrate: 6.4%)
# 📊 Verarbeitet: 196,000 Records (Erfolgsrate: 6.4%)
# 📊 Verarbeitet: 197,000 Records (Erfolgsrate: 6.4%)
# 📊 Verarbeitet: 197,000 Records (Erfolgsrate: 6.4%)
# 📊 Verarbeitet: 198,000 Records (Erfolgsrate: 6.5%)
# 📊 Verarbeitet: 198,000 Records (Erfolgsrate: 6.5%)
# 📊 Verarbeitet: 199,000 Records (Erfolgsrate: 6.5%)
# 📊 Verarbeitet: 199,000 Records (Erfolgsrate: 6.5%)
# 📊 Verarbeitet: 200,000 Records (Erfolgsrate: 6.6%)
# 📊 Verarbeitet: 200,000 Records (Erfolgsrate: 6.6%)
# 📊 Verarbeitet: 201,000 Records (Erfolgsrate: 6.6%)
# 📊 Verarbeitet: 201,000 Records (Erfolgsrate: 6.6%)
# 📊 Verarbeitet: 202,000 Records (Erfolgsrate: 6.6%)
# 📊 Verarbeitet: 202,000 Records (Erfolgsrate: 6.6%)
# 📊 Verarbeitet: 203,000 Records (Erfolgsrate: 6.7%)
# 📊 Verarbeitet: 203,000 Records (Erfolgsrate: 6.7%)
# 📊 Verarbeitet: 204,000 Records (Erfolgsrate: 6.7%)
# 📊 Verarbeitet: 204,000 Records (Erfolgsrate: 6.7%)
# 📊 Verarbeitet: 205,000 Records (Erfolgsrate: 6.7%)
# 📊 Verarbeitet: 205,000 Records (Erfolgsrate: 6.7%)
# 📊 Verarbeitet: 206,000 Records (Erfolgsrate: 6.8%)
# 📊 Verarbeitet: 206,000 Records (Erfolgsrate: 6.8%)
# 📊 Verarbeitet: 207,000 Records (Erfolgsrate: 6.8%)
# 📊 Verarbeitet: 207,000 Records (Erfolgsrate: 6.8%)
# 📊 Verarbeitet: 208,000 Records (Erfolgsrate: 6.8%)
# 📊 Verarbeitet: 208,000 Records (Erfolgsrate: 6.8%)
# ⚠️  Record ohne Kernfelder: ID=00506
# ⚠️  Record ohne Kernfelder: ID=00506
# 📊 Verarbeitet: 209,000 Records (Erfolgsrate: 6.9%)
# 📊 Verarbeitet: 209,000 Records (Erfolgsrate: 6.9%)
# 📊 Verarbeitet: 210,000 Records (Erfolgsrate: 6.9%)
# 📊 Verarbeitet: 210,000 Records (Erfolgsrate: 6.9%)
# 📊 Verarbeitet: 211,000 Records (Erfolgsrate: 7.0%)
# 📊 Verarbeitet: 211,000 Records (Erfolgsrate: 7.0%)
# ⚠️  Record ohne Kernfelder: ID=00418
# ⚠️  Record ohne Kernfelder: ID=00418
# 📊 Verarbeitet: 212,000 Records (Erfolgsrate: 7.0%)
# 📊 Verarbeitet: 212,000 Records (Erfolgsrate: 7.0%)
# 📊 Verarbeitet: 213,000 Records (Erfolgsrate: 7.1%)
# 📊 Verarbeitet: 213,000 Records (Erfolgsrate: 7.1%)
# 📊 Verarbeitet: 214,000 Records (Erfolgsrate: 7.1%)
# 📊 Verarbeitet: 214,000 Records (Erfolgsrate: 7.1%)
# 📊 Verarbeitet: 215,000 Records (Erfolgsrate: 7.1%)
# 📊 Verarbeitet: 215,000 Records (Erfolgsrate: 7.1%)
# 📊 Verarbeitet: 216,000 Records (Erfolgsrate: 7.2%)
# 📊 Verarbeitet: 216,000 Records (Erfolgsrate: 7.2%)
# 📊 Verarbeitet: 217,000 Records (Erfolgsrate: 7.2%)
# ⚠️  Record ohne Kernfelder: ID=00957
# 📊 Verarbeitet: 217,000 Records (Erfolgsrate: 7.2%)
# ⚠️  Record ohne Kernfelder: ID=00957
# ⚠️  Record ohne Kernfelder: ID=00957
# ⚠️  Record ohne Kernfelder: ID=00957
# 📊 Verarbeitet: 218,000 Records (Erfolgsrate: 7.2%)
# 📊 Verarbeitet: 218,000 Records (Erfolgsrate: 7.2%)
# 📊 Verarbeitet: 219,000 Records (Erfolgsrate: 7.3%)
# 📊 Verarbeitet: 219,000 Records (Erfolgsrate: 7.3%)
# 📊 Verarbeitet: 220,000 Records (Erfolgsrate: 7.3%)
# 📊 Verarbeitet: 220,000 Records (Erfolgsrate: 7.3%)
# 📊 Verarbeitet: 221,000 Records (Erfolgsrate: 7.4%)
# 📊 Verarbeitet: 221,000 Records (Erfolgsrate: 7.4%)
# 📊 Verarbeitet: 222,000 Records (Erfolgsrate: 7.4%)
# 📊 Verarbeitet: 222,000 Records (Erfolgsrate: 7.4%)
# 📊 Verarbeitet: 223,000 Records (Erfolgsrate: 7.4%)
# 📊 Verarbeitet: 223,000 Records (Erfolgsrate: 7.4%)
# 📊 Verarbeitet: 224,000 Records (Erfolgsrate: 7.4%)
# 📊 Verarbeitet: 224,000 Records (Erfolgsrate: 7.4%)
# 📊 Verarbeitet: 225,000 Records (Erfolgsrate: 7.5%)
# 📊 Verarbeitet: 225,000 Records (Erfolgsrate: 7.5%)
# 📊 Verarbeitet: 226,000 Records (Erfolgsrate: 7.5%)
# 📊 Verarbeitet: 226,000 Records (Erfolgsrate: 7.5%)
# 📊 Verarbeitet: 227,000 Records (Erfolgsrate: 7.5%)
# 📊 Verarbeitet: 227,000 Records (Erfolgsrate: 7.5%)
# 📊 Verarbeitet: 228,000 Records (Erfolgsrate: 7.5%)
# 📊 Verarbeitet: 228,000 Records (Erfolgsrate: 7.5%)
# 📊 Verarbeitet: 229,000 Records (Erfolgsrate: 7.6%)
# 📊 Verarbeitet: 229,000 Records (Erfolgsrate: 7.6%)
# 📊 Verarbeitet: 230,000 Records (Erfolgsrate: 7.6%)
# 📊 Verarbeitet: 230,000 Records (Erfolgsrate: 7.6%)
# 📊 Verarbeitet: 231,000 Records (Erfolgsrate: 7.6%)
# 📊 Verarbeitet: 231,000 Records (Erfolgsrate: 7.6%)
# 📊 Verarbeitet: 232,000 Records (Erfolgsrate: 7.6%)
# 📊 Verarbeitet: 232,000 Records (Erfolgsrate: 7.6%)
# 📊 Verarbeitet: 233,000 Records (Erfolgsrate: 7.7%)
# 📊 Verarbeitet: 233,000 Records (Erfolgsrate: 7.7%)
# 📊 Verarbeitet: 234,000 Records (Erfolgsrate: 7.7%)
# 📊 Verarbeitet: 234,000 Records (Erfolgsrate: 7.7%)
# 📊 Verarbeitet: 235,000 Records (Erfolgsrate: 7.7%)
# 📊 Verarbeitet: 235,000 Records (Erfolgsrate: 7.7%)
# 📊 Verarbeitet: 236,000 Records (Erfolgsrate: 7.7%)
# 📊 Verarbeitet: 236,000 Records (Erfolgsrate: 7.7%)
# 📊 Verarbeitet: 237,000 Records (Erfolgsrate: 7.7%)
# 📊 Verarbeitet: 237,000 Records (Erfolgsrate: 7.7%)
# 📊 Verarbeitet: 238,000 Records (Erfolgsrate: 7.8%)
# 📊 Verarbeitet: 238,000 Records (Erfolgsrate: 7.8%)
# 📊 Verarbeitet: 239,000 Records (Erfolgsrate: 7.8%)
# 📊 Verarbeitet: 239,000 Records (Erfolgsrate: 7.8%)
# 📊 Verarbeitet: 240,000 Records (Erfolgsrate: 7.8%)
# 📊 Verarbeitet: 240,000 Records (Erfolgsrate: 7.8%)
# 📊 Verarbeitet: 241,000 Records (Erfolgsrate: 7.8%)
# 📊 Verarbeitet: 241,000 Records (Erfolgsrate: 7.8%)
# 📊 Verarbeitet: 242,000 Records (Erfolgsrate: 7.8%)
# 📊 Verarbeitet: 242,000 Records (Erfolgsrate: 7.8%)
# 📊 Verarbeitet: 243,000 Records (Erfolgsrate: 7.8%)
# 📊 Verarbeitet: 243,000 Records (Erfolgsrate: 7.8%)
# 📊 Verarbeitet: 244,000 Records (Erfolgsrate: 7.9%)
# 📊 Verarbeitet: 244,000 Records (Erfolgsrate: 7.9%)
# 📊 Verarbeitet: 245,000 Records (Erfolgsrate: 7.9%)
# 📊 Verarbeitet: 245,000 Records (Erfolgsrate: 7.9%)
# 📊 Verarbeitet: 246,000 Records (Erfolgsrate: 7.9%)
# 📊 Verarbeitet: 246,000 Records (Erfolgsrate: 7.9%)
# 📊 Verarbeitet: 247,000 Records (Erfolgsrate: 7.9%)
# 📊 Verarbeitet: 247,000 Records (Erfolgsrate: 7.9%)
# 📊 Verarbeitet: 248,000 Records (Erfolgsrate: 7.9%)
# 📊 Verarbeitet: 248,000 Records (Erfolgsrate: 7.9%)
# 📊 Verarbeitet: 249,000 Records (Erfolgsrate: 7.9%)
# 📊 Verarbeitet: 249,000 Records (Erfolgsrate: 7.9%)
# 📊 Verarbeitet: 250,000 Records (Erfolgsrate: 7.9%)
# 📊 Verarbeitet: 250,000 Records (Erfolgsrate: 7.9%)
# 📊 Verarbeitet: 251,000 Records (Erfolgsrate: 8.0%)
# 📊 Verarbeitet: 251,000 Records (Erfolgsrate: 8.0%)
# 📊 Verarbeitet: 252,000 Records (Erfolgsrate: 8.0%)
# 📊 Verarbeitet: 252,000 Records (Erfolgsrate: 8.0%)
# 📊 Verarbeitet: 253,000 Records (Erfolgsrate: 8.0%)
# 📊 Verarbeitet: 253,000 Records (Erfolgsrate: 8.0%)
# 📊 Verarbeitet: 254,000 Records (Erfolgsrate: 8.0%)
# 📊 Verarbeitet: 254,000 Records (Erfolgsrate: 8.0%)
# 📊 Verarbeitet: 255,000 Records (Erfolgsrate: 8.0%)
# 📊 Verarbeitet: 255,000 Records (Erfolgsrate: 8.0%)
# 📊 Verarbeitet: 256,000 Records (Erfolgsrate: 8.0%)
# 📊 Verarbeitet: 256,000 Records (Erfolgsrate: 8.0%)
# 📊 Verarbeitet: 257,000 Records (Erfolgsrate: 8.0%)
# 📊 Verarbeitet: 257,000 Records (Erfolgsrate: 8.0%)
# ⚠️  Record ohne Kernfelder: ID=00620
# ⚠️  Record ohne Kernfelder: ID=00620
# 📊 Verarbeitet: 258,000 Records (Erfolgsrate: 8.0%)
# 📊 Verarbeitet: 258,000 Records (Erfolgsrate: 8.0%)
# 📊 Verarbeitet: 259,000 Records (Erfolgsrate: 8.0%)
# 📊 Verarbeitet: 259,000 Records (Erfolgsrate: 8.0%)
# 📊 Verarbeitet: 260,000 Records (Erfolgsrate: 8.1%)
# 📊 Verarbeitet: 260,000 Records (Erfolgsrate: 8.1%)
# 📊 Verarbeitet: 261,000 Records (Erfolgsrate: 8.1%)
# 📊 Verarbeitet: 261,000 Records (Erfolgsrate: 8.1%)
# 📊 Verarbeitet: 262,000 Records (Erfolgsrate: 8.1%)
# 📊 Verarbeitet: 262,000 Records (Erfolgsrate: 8.1%)
# 📊 Verarbeitet: 263,000 Records (Erfolgsrate: 8.1%)
# 📊 Verarbeitet: 263,000 Records (Erfolgsrate: 8.1%)
# 📊 Verarbeitet: 264,000 Records (Erfolgsrate: 8.1%)
# 📊 Verarbeitet: 264,000 Records (Erfolgsrate: 8.1%)
# 📊 Verarbeitet: 265,000 Records (Erfolgsrate: 8.1%)
# 📊 Verarbeitet: 265,000 Records (Erfolgsrate: 8.1%)
# ⚠️  Record ohne Kernfelder: ID=00437
# ⚠️  Record ohne Kernfelder: ID=00437
# 📊 Verarbeitet: 266,000 Records (Erfolgsrate: 8.2%)
# 📊 Verarbeitet: 266,000 Records (Erfolgsrate: 8.2%)
# 📊 Verarbeitet: 267,000 Records (Erfolgsrate: 8.2%)
# 📊 Verarbeitet: 267,000 Records (Erfolgsrate: 8.2%)
# 📊 Verarbeitet: 268,000 Records (Erfolgsrate: 8.3%)
# 📊 Verarbeitet: 268,000 Records (Erfolgsrate: 8.3%)
# 📊 Verarbeitet: 269,000 Records (Erfolgsrate: 8.3%)
# 📊 Verarbeitet: 269,000 Records (Erfolgsrate: 8.3%)
# 📊 Verarbeitet: 270,000 Records (Erfolgsrate: 8.3%)
# 📊 Verarbeitet: 270,000 Records (Erfolgsrate: 8.3%)
# 📊 Verarbeitet: 271,000 Records (Erfolgsrate: 8.3%)
# 📊 Verarbeitet: 271,000 Records (Erfolgsrate: 8.3%)
# 📊 Verarbeitet: 272,000 Records (Erfolgsrate: 8.3%)
# 📊 Verarbeitet: 272,000 Records (Erfolgsrate: 8.3%)
# 📊 Verarbeitet: 273,000 Records (Erfolgsrate: 8.4%)
# 📊 Verarbeitet: 273,000 Records (Erfolgsrate: 8.4%)
# 📊 Verarbeitet: 274,000 Records (Erfolgsrate: 8.4%)
# 📊 Verarbeitet: 274,000 Records (Erfolgsrate: 8.4%)
# 📊 Verarbeitet: 275,000 Records (Erfolgsrate: 8.4%)
# 📊 Verarbeitet: 275,000 Records (Erfolgsrate: 8.4%)
# 📊 Verarbeitet: 276,000 Records (Erfolgsrate: 8.4%)
# 📊 Verarbeitet: 276,000 Records (Erfolgsrate: 8.4%)
# 📊 Verarbeitet: 277,000 Records (Erfolgsrate: 8.4%)
# 📊 Verarbeitet: 277,000 Records (Erfolgsrate: 8.4%)
# 📊 Verarbeitet: 278,000 Records (Erfolgsrate: 8.4%)
# 📊 Verarbeitet: 278,000 Records (Erfolgsrate: 8.4%)
# 📊 Verarbeitet: 279,000 Records (Erfolgsrate: 8.4%)
# 📊 Verarbeitet: 279,000 Records (Erfolgsrate: 8.4%)
# 📊 Verarbeitet: 280,000 Records (Erfolgsrate: 8.5%)
# 📊 Verarbeitet: 280,000 Records (Erfolgsrate: 8.5%)
# 📊 Verarbeitet: 281,000 Records (Erfolgsrate: 8.5%)
# 📊 Verarbeitet: 281,000 Records (Erfolgsrate: 8.5%)
# 📊 Verarbeitet: 282,000 Records (Erfolgsrate: 8.5%)
# 📊 Verarbeitet: 282,000 Records (Erfolgsrate: 8.5%)
# 📊 Verarbeitet: 283,000 Records (Erfolgsrate: 8.5%)
# 📊 Verarbeitet: 283,000 Records (Erfolgsrate: 8.5%)
# 📊 Verarbeitet: 284,000 Records (Erfolgsrate: 8.5%)
# 📊 Verarbeitet: 284,000 Records (Erfolgsrate: 8.5%)
# 📊 Verarbeitet: 285,000 Records (Erfolgsrate: 8.5%)
# 📊 Verarbeitet: 285,000 Records (Erfolgsrate: 8.5%)
# 📊 Verarbeitet: 286,000 Records (Erfolgsrate: 8.5%)
# 📊 Verarbeitet: 286,000 Records (Erfolgsrate: 8.5%)
# 📊 Verarbeitet: 287,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 287,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 288,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 288,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 289,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 289,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 290,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 290,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 291,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 291,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 292,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 292,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 293,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 293,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 294,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 294,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 295,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 295,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 296,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 296,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 297,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 297,000 Records (Erfolgsrate: 8.6%)
# 📊 Verarbeitet: 298,000 Records (Erfolgsrate: 8.7%)
# 📊 Verarbeitet: 298,000 Records (Erfolgsrate: 8.7%)
# 📊 Verarbeitet: 299,000 Records (Erfolgsrate: 8.7%)
# 📊 Verarbeitet: 299,000 Records (Erfolgsrate: 8.7%)
# 📊 Verarbeitet: 300,000 Records (Erfolgsrate: 8.7%)
# 📊 Verarbeitet: 300,000 Records (Erfolgsrate: 8.7%)
# 📊 Verarbeitet: 301,000 Records (Erfolgsrate: 8.7%)
# 📊 Verarbeitet: 301,000 Records (Erfolgsrate: 8.7%)
# 📊 Verarbeitet: 302,000 Records (Erfolgsrate: 8.7%)
# 📊 Verarbeitet: 302,000 Records (Erfolgsrate: 8.7%)
# 📊 Verarbeitet: 303,000 Records (Erfolgsrate: 8.7%)
# 📊 Verarbeitet: 303,000 Records (Erfolgsrate: 8.7%)
# 📊 Verarbeitet: 304,000 Records (Erfolgsrate: 8.7%)
# 📊 Verarbeitet: 304,000 Records (Erfolgsrate: 8.7%)
# 📊 Verarbeitet: 305,000 Records (Erfolgsrate: 8.7%)
# 📊 Verarbeitet: 305,000 Records (Erfolgsrate: 8.7%)
# 📊 Verarbeitet: 306,000 Records (Erfolgsrate: 8.8%)
# 📊 Verarbeitet: 306,000 Records (Erfolgsrate: 8.8%)
# 📊 Verarbeitet: 307,000 Records (Erfolgsrate: 8.8%)
# 📊 Verarbeitet: 307,000 Records (Erfolgsrate: 8.8%)
# 📊 Verarbeitet: 308,000 Records (Erfolgsrate: 8.8%)
# 📊 Verarbeitet: 308,000 Records (Erfolgsrate: 8.8%)
# 📊 Verarbeitet: 309,000 Records (Erfolgsrate: 8.8%)
# 📊 Verarbeitet: 309,000 Records (Erfolgsrate: 8.8%)
# 📊 Verarbeitet: 310,000 Records (Erfolgsrate: 8.8%)
# 📊 Verarbeitet: 310,000 Records (Erfolgsrate: 8.8%)
# 📊 Verarbeitet: 311,000 Records (Erfolgsrate: 8.8%)
# 📊 Verarbeitet: 311,000 Records (Erfolgsrate: 8.8%)
# 📊 Verarbeitet: 312,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 312,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 313,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 313,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 314,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 314,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 315,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 315,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 316,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 316,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 317,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 317,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 318,000 Records (Erfolgsrate: 9.0%)
# 📊 Verarbeitet: 318,000 Records (Erfolgsrate: 9.0%)
# 📊 Verarbeitet: 319,000 Records (Erfolgsrate: 9.0%)
# 📊 Verarbeitet: 319,000 Records (Erfolgsrate: 9.0%)
# 📊 Verarbeitet: 320,000 Records (Erfolgsrate: 9.0%)
# 📊 Verarbeitet: 320,000 Records (Erfolgsrate: 9.0%)
# 📊 Verarbeitet: 321,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 321,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 322,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 322,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 323,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 323,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 324,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 324,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 325,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 325,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 326,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 326,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 327,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 327,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 328,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 328,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 329,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 329,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 330,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 330,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 331,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 331,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 332,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 332,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 333,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 333,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 334,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 334,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 335,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 335,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 336,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 336,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 337,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 337,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 338,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 338,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 339,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 339,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 340,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 340,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 341,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 341,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 342,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 342,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 343,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 343,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 344,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 344,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 345,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 345,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 346,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 346,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 347,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 347,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 348,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 348,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 349,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 349,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 350,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 350,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 351,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 351,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 352,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 352,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 353,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 353,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 354,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 354,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 355,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 355,000 Records (Erfolgsrate: 8.9%)
# 📊 Verarbeitet: 356,000 Records (Erfolgsrate: 9.0%)
# 📊 Verarbeitet: 356,000 Records (Erfolgsrate: 9.0%)
# 📊 Verarbeitet: 357,000 Records (Erfolgsrate: 9.0%)
# 📊 Verarbeitet: 357,000 Records (Erfolgsrate: 9.0%)
# 📊 Verarbeitet: 358,000 Records (Erfolgsrate: 9.0%)
# 📊 Verarbeitet: 358,000 Records (Erfolgsrate: 9.0%)
# 📊 Verarbeitet: 359,000 Records (Erfolgsrate: 9.1%)
# 📊 Verarbeitet: 359,000 Records (Erfolgsrate: 9.1%)
# 📊 Verarbeitet: 360,000 Records (Erfolgsrate: 9.1%)
# 📊 Verarbeitet: 360,000 Records (Erfolgsrate: 9.1%)
# 📊 Verarbeitet: 361,000 Records (Erfolgsrate: 9.1%)
# 📊 Verarbeitet: 361,000 Records (Erfolgsrate: 9.1%)
# 📊 Verarbeitet: 362,000 Records (Erfolgsrate: 9.1%)
# 📊 Verarbeitet: 362,000 Records (Erfolgsrate: 9.1%)
# 📊 Verarbeitet: 363,000 Records (Erfolgsrate: 9.1%)
# 📊 Verarbeitet: 363,000 Records (Erfolgsrate: 9.1%)
# 📊 Verarbeitet: 364,000 Records (Erfolgsrate: 9.1%)
# 📊 Verarbeitet: 364,000 Records (Erfolgsrate: 9.1%)
# 📊 Verarbeitet: 365,000 Records (Erfolgsrate: 9.2%)
# 📊 Verarbeitet: 365,000 Records (Erfolgsrate: 9.2%)
# 📊 Verarbeitet: 366,000 Records (Erfolgsrate: 9.2%)
# 📊 Verarbeitet: 366,000 Records (Erfolgsrate: 9.2%)
# 📊 Verarbeitet: 367,000 Records (Erfolgsrate: 9.2%)
# 📊 Verarbeitet: 367,000 Records (Erfolgsrate: 9.2%)
# 📊 Verarbeitet: 368,000 Records (Erfolgsrate: 9.2%)
# 📊 Verarbeitet: 368,000 Records (Erfolgsrate: 9.2%)
# 📊 Verarbeitet: 369,000 Records (Erfolgsrate: 9.2%)
# 📊 Verarbeitet: 369,000 Records (Erfolgsrate: 9.2%)
# 📊 Verarbeitet: 370,000 Records (Erfolgsrate: 9.2%)
# 📊 Verarbeitet: 370,000 Records (Erfolgsrate: 9.2%)
# 📊 Verarbeitet: 371,000 Records (Erfolgsrate: 9.3%)
# 📊 Verarbeitet: 371,000 Records (Erfolgsrate: 9.3%)
# 📊 Verarbeitet: 372,000 Records (Erfolgsrate: 9.3%)
# 📊 Verarbeitet: 372,000 Records (Erfolgsrate: 9.3%)
# 📊 Verarbeitet: 373,000 Records (Erfolgsrate: 9.3%)
# 📊 Verarbeitet: 373,000 Records (Erfolgsrate: 9.3%)
# 📊 Verarbeitet: 374,000 Records (Erfolgsrate: 9.3%)
# 📊 Verarbeitet: 374,000 Records (Erfolgsrate: 9.3%)
# 📊 Verarbeitet: 375,000 Records (Erfolgsrate: 9.3%)
# 📊 Verarbeitet: 375,000 Records (Erfolgsrate: 9.3%)
# 📊 Verarbeitet: 376,000 Records (Erfolgsrate: 9.5%)
# 📊 Verarbeitet: 376,000 Records (Erfolgsrate: 9.5%)
# 📊 Verarbeitet: 377,000 Records (Erfolgsrate: 9.7%)
# 📊 Verarbeitet: 377,000 Records (Erfolgsrate: 9.7%)
# 📊 Verarbeitet: 378,000 Records (Erfolgsrate: 9.9%)
# 📊 Verarbeitet: 378,000 Records (Erfolgsrate: 9.9%)
# 📊 Verarbeitet: 379,000 Records (Erfolgsrate: 10.1%)
# 📊 Verarbeitet: 379,000 Records (Erfolgsrate: 10.1%)
# 📊 Verarbeitet: 380,000 Records (Erfolgsrate: 10.3%)
# 📊 Verarbeitet: 380,000 Records (Erfolgsrate: 10.3%)
# 📊 Verarbeitet: 381,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 381,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 382,000 Records (Erfolgsrate: 10.8%)
# 📊 Verarbeitet: 382,000 Records (Erfolgsrate: 10.8%)
# 📊 Verarbeitet: 383,000 Records (Erfolgsrate: 10.9%)
# 📊 Verarbeitet: 383,000 Records (Erfolgsrate: 10.9%)
# 📊 Verarbeitet: 384,000 Records (Erfolgsrate: 11.0%)
# 📊 Verarbeitet: 384,000 Records (Erfolgsrate: 11.0%)
# 📊 Verarbeitet: 385,000 Records (Erfolgsrate: 11.0%)
# 📊 Verarbeitet: 385,000 Records (Erfolgsrate: 11.0%)
# 📊 Verarbeitet: 386,000 Records (Erfolgsrate: 11.0%)
# 📊 Verarbeitet: 386,000 Records (Erfolgsrate: 11.0%)
# 📊 Verarbeitet: 387,000 Records (Erfolgsrate: 11.0%)
# 📊 Verarbeitet: 387,000 Records (Erfolgsrate: 11.0%)
# 📊 Verarbeitet: 388,000 Records (Erfolgsrate: 11.0%)
# 📊 Verarbeitet: 388,000 Records (Erfolgsrate: 11.0%)
# 📊 Verarbeitet: 389,000 Records (Erfolgsrate: 10.9%)
# 📊 Verarbeitet: 389,000 Records (Erfolgsrate: 10.9%)
# 📊 Verarbeitet: 390,000 Records (Erfolgsrate: 10.9%)
# 📊 Verarbeitet: 390,000 Records (Erfolgsrate: 10.9%)
# 📊 Verarbeitet: 391,000 Records (Erfolgsrate: 10.9%)
# 📊 Verarbeitet: 391,000 Records (Erfolgsrate: 10.9%)
# 📊 Verarbeitet: 392,000 Records (Erfolgsrate: 10.9%)
# 📊 Verarbeitet: 392,000 Records (Erfolgsrate: 10.9%)
# 📊 Verarbeitet: 393,000 Records (Erfolgsrate: 10.9%)
# 📊 Verarbeitet: 393,000 Records (Erfolgsrate: 10.9%)
# 📊 Verarbeitet: 394,000 Records (Erfolgsrate: 10.9%)
# 📊 Verarbeitet: 394,000 Records (Erfolgsrate: 10.9%)
# 📊 Verarbeitet: 395,000 Records (Erfolgsrate: 10.8%)
# 📊 Verarbeitet: 395,000 Records (Erfolgsrate: 10.8%)
# 📊 Verarbeitet: 396,000 Records (Erfolgsrate: 10.8%)
# 📊 Verarbeitet: 396,000 Records (Erfolgsrate: 10.8%)
# 📊 Verarbeitet: 397,000 Records (Erfolgsrate: 10.8%)
# 📊 Verarbeitet: 397,000 Records (Erfolgsrate: 10.8%)
# 📊 Verarbeitet: 398,000 Records (Erfolgsrate: 10.8%)
# 📊 Verarbeitet: 398,000 Records (Erfolgsrate: 10.8%)
# 📊 Verarbeitet: 399,000 Records (Erfolgsrate: 10.8%)
# 📊 Verarbeitet: 399,000 Records (Erfolgsrate: 10.8%)
# 📊 Verarbeitet: 400,000 Records (Erfolgsrate: 10.8%)
# 📊 Verarbeitet: 400,000 Records (Erfolgsrate: 10.8%)
# 📊 Verarbeitet: 401,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 401,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 402,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 402,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 403,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 403,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 404,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 404,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 405,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 405,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 406,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 406,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 407,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 407,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 408,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 408,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 409,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 409,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 410,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 410,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 411,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 411,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 412,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 412,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 413,000 Records (Erfolgsrate: 10.6%)
# 📊 Verarbeitet: 413,000 Records (Erfolgsrate: 10.6%)
# 📊 Verarbeitet: 414,000 Records (Erfolgsrate: 10.6%)
# 📊 Verarbeitet: 414,000 Records (Erfolgsrate: 10.6%)
# 📊 Verarbeitet: 415,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 415,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 416,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 416,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 417,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 417,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 418,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 418,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 419,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 419,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 420,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 420,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 421,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 421,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 422,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 422,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 423,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 423,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 424,000 Records (Erfolgsrate: 10.8%)
# 📊 Verarbeitet: 424,000 Records (Erfolgsrate: 10.8%)
# 📊 Verarbeitet: 425,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 425,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 426,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 426,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 427,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 427,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 428,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 428,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 429,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 429,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 430,000 Records (Erfolgsrate: 10.6%)
# 📊 Verarbeitet: 430,000 Records (Erfolgsrate: 10.6%)
# 📊 Verarbeitet: 431,000 Records (Erfolgsrate: 10.6%)
# 📊 Verarbeitet: 431,000 Records (Erfolgsrate: 10.6%)
# 📊 Verarbeitet: 432,000 Records (Erfolgsrate: 10.6%)
# 📊 Verarbeitet: 432,000 Records (Erfolgsrate: 10.6%)
# 📊 Verarbeitet: 433,000 Records (Erfolgsrate: 10.6%)
# 📊 Verarbeitet: 433,000 Records (Erfolgsrate: 10.6%)
# 📊 Verarbeitet: 434,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 434,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 435,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 435,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 436,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 436,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 437,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 437,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 438,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 438,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 439,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 439,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 440,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 440,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 441,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 441,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 442,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 442,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 443,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 443,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 444,000 Records (Erfolgsrate: 10.3%)
# 📊 Verarbeitet: 444,000 Records (Erfolgsrate: 10.3%)
# 📊 Verarbeitet: 445,000 Records (Erfolgsrate: 10.3%)
# 📊 Verarbeitet: 445,000 Records (Erfolgsrate: 10.3%)
# 📊 Verarbeitet: 446,000 Records (Erfolgsrate: 10.3%)
# 📊 Verarbeitet: 446,000 Records (Erfolgsrate: 10.3%)
# 📊 Verarbeitet: 447,000 Records (Erfolgsrate: 10.3%)
# 📊 Verarbeitet: 447,000 Records (Erfolgsrate: 10.3%)
# 📊 Verarbeitet: 448,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 448,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 449,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 449,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 450,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 450,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 451,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 451,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 452,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 452,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 453,000 Records (Erfolgsrate: 10.1%)
# 📊 Verarbeitet: 453,000 Records (Erfolgsrate: 10.1%)
# 📊 Verarbeitet: 454,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 454,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 455,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 455,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 456,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 456,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 457,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 457,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 458,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 458,000 Records (Erfolgsrate: 10.2%)
# 📊 Verarbeitet: 459,000 Records (Erfolgsrate: 10.3%)
# 📊 Verarbeitet: 459,000 Records (Erfolgsrate: 10.3%)
# 📊 Verarbeitet: 460,000 Records (Erfolgsrate: 10.3%)
# 📊 Verarbeitet: 460,000 Records (Erfolgsrate: 10.3%)
# 📊 Verarbeitet: 461,000 Records (Erfolgsrate: 10.3%)
# 📊 Verarbeitet: 461,000 Records (Erfolgsrate: 10.3%)
# 📊 Verarbeitet: 462,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 462,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 463,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 463,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 464,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 464,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 465,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 465,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 466,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 466,000 Records (Erfolgsrate: 10.4%)
# 📊 Verarbeitet: 467,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 467,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 468,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 468,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 469,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 469,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 470,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 470,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 471,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 471,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 472,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 472,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 473,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 473,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 474,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 474,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 475,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 475,000 Records (Erfolgsrate: 10.5%)
# 📊 Verarbeitet: 476,000 Records (Erfolgsrate: 10.6%)
# 📊 Verarbeitet: 476,000 Records (Erfolgsrate: 10.6%)
# 📊 Verarbeitet: 477,000 Records (Erfolgsrate: 10.6%)
# 📊 Verarbeitet: 477,000 Records (Erfolgsrate: 10.6%)
# 📊 Verarbeitet: 478,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 478,000 Records (Erfolgsrate: 10.7%)
# 📊 Verarbeitet: 479,000 Records (Erfolgsrate: 10.9%)
# 📊 Verarbeitet: 479,000 Records (Erfolgsrate: 10.9%)
# 📊 Verarbeitet: 480,000 Records (Erfolgsrate: 11.1%)
# 📊 Verarbeitet: 480,000 Records (Erfolgsrate: 11.1%)
# 📊 Verarbeitet: 481,000 Records (Erfolgsrate: 11.2%)
# 📊 Verarbeitet: 481,000 Records (Erfolgsrate: 11.2%)
# 📊 Verarbeitet: 482,000 Records (Erfolgsrate: 11.4%)
# 📊 Verarbeitet: 482,000 Records (Erfolgsrate: 11.4%)
# 📊 Verarbeitet: 483,000 Records (Erfolgsrate: 11.5%)
# 📊 Verarbeitet: 483,000 Records (Erfolgsrate: 11.5%)
# 📊 Verarbeitet: 484,000 Records (Erfolgsrate: 11.7%)
# 📊 Verarbeitet: 484,000 Records (Erfolgsrate: 11.7%)
# 📊 Verarbeitet: 485,000 Records (Erfolgsrate: 11.8%)
# 📊 Verarbeitet: 485,000 Records (Erfolgsrate: 11.8%)
# 📊 Verarbeitet: 486,000 Records (Erfolgsrate: 12.0%)
# 📊 Verarbeitet: 486,000 Records (Erfolgsrate: 12.0%)
# 📊 Verarbeitet: 487,000 Records (Erfolgsrate: 12.1%)
# 📊 Verarbeitet: 487,000 Records (Erfolgsrate: 12.1%)
# 📊 Verarbeitet: 488,000 Records (Erfolgsrate: 12.2%)
# 📊 Verarbeitet: 488,000 Records (Erfolgsrate: 12.2%)
# 📊 Verarbeitet: 489,000 Records (Erfolgsrate: 12.3%)
# 📊 Verarbeitet: 489,000 Records (Erfolgsrate: 12.3%)
# 📊 Verarbeitet: 490,000 Records (Erfolgsrate: 12.5%)
# 📊 Verarbeitet: 490,000 Records (Erfolgsrate: 12.5%)
# 📊 Verarbeitet: 491,000 Records (Erfolgsrate: 12.6%)
# 📊 Verarbeitet: 491,000 Records (Erfolgsrate: 12.6%)
# 📊 Verarbeitet: 492,000 Records (Erfolgsrate: 12.8%)
# 📊 Verarbeitet: 492,000 Records (Erfolgsrate: 12.8%)
# 📊 Verarbeitet: 493,000 Records (Erfolgsrate: 13.0%)
# 📊 Verarbeitet: 493,000 Records (Erfolgsrate: 13.0%)
# 📊 Verarbeitet: 494,000 Records (Erfolgsrate: 13.1%)
# 📊 Verarbeitet: 494,000 Records (Erfolgsrate: 13.1%)
# 📊 Verarbeitet: 495,000 Records (Erfolgsrate: 13.2%)
# 📊 Verarbeitet: 495,000 Records (Erfolgsrate: 13.2%)
# 📊 Verarbeitet: 496,000 Records (Erfolgsrate: 13.4%)
# 📊 Verarbeitet: 496,000 Records (Erfolgsrate: 13.4%)
# 📊 Verarbeitet: 497,000 Records (Erfolgsrate: 13.5%)
# 📊 Verarbeitet: 497,000 Records (Erfolgsrate: 13.5%)
# 📊 Verarbeitet: 498,000 Records (Erfolgsrate: 13.7%)
# 📊 Verarbeitet: 498,000 Records (Erfolgsrate: 13.7%)
# 📊 Verarbeitet: 499,000 Records (Erfolgsrate: 13.8%)
# 📊 Verarbeitet: 499,000 Records (Erfolgsrate: 13.8%)
# 📊 Verarbeitet: 500,000 Records (Erfolgsrate: 13.9%)
# 📊 Verarbeitet: 500,000 Records (Erfolgsrate: 13.9%)
# 📊 Verarbeitet: 501,000 Records (Erfolgsrate: 14.1%)
# 📊 Verarbeitet: 501,000 Records (Erfolgsrate: 14.1%)
# 📊 Verarbeitet: 502,000 Records (Erfolgsrate: 14.2%)
# 📊 Verarbeitet: 502,000 Records (Erfolgsrate: 14.2%)
# 📊 Verarbeitet: 503,000 Records (Erfolgsrate: 14.4%)
# 📊 Verarbeitet: 503,000 Records (Erfolgsrate: 14.4%)
# 📊 Verarbeitet: 504,000 Records (Erfolgsrate: 14.6%)
# 📊 Verarbeitet: 504,000 Records (Erfolgsrate: 14.6%)
# 📊 Verarbeitet: 505,000 Records (Erfolgsrate: 14.7%)
# 📊 Verarbeitet: 505,000 Records (Erfolgsrate: 14.7%)
# 📊 Verarbeitet: 506,000 Records (Erfolgsrate: 14.9%)
# 📊 Verarbeitet: 506,000 Records (Erfolgsrate: 14.9%)
# 📊 Verarbeitet: 507,000 Records (Erfolgsrate: 15.0%)
# 📊 Verarbeitet: 507,000 Records (Erfolgsrate: 15.0%)
# 📊 Verarbeitet: 508,000 Records (Erfolgsrate: 15.1%)
# 📊 Verarbeitet: 508,000 Records (Erfolgsrate: 15.1%)
# 📊 Verarbeitet: 509,000 Records (Erfolgsrate: 15.3%)
# 📊 Verarbeitet: 509,000 Records (Erfolgsrate: 15.3%)
# 📊 Verarbeitet: 510,000 Records (Erfolgsrate: 15.4%)
# 📊 Verarbeitet: 510,000 Records (Erfolgsrate: 15.4%)
# 📊 Verarbeitet: 511,000 Records (Erfolgsrate: 15.6%)
# 📊 Verarbeitet: 511,000 Records (Erfolgsrate: 15.6%)
# 📊 Verarbeitet: 512,000 Records (Erfolgsrate: 15.7%)
# 📊 Verarbeitet: 512,000 Records (Erfolgsrate: 15.7%)
# 📊 Verarbeitet: 513,000 Records (Erfolgsrate: 15.9%)
# 📊 Verarbeitet: 513,000 Records (Erfolgsrate: 15.9%)
# 📊 Verarbeitet: 514,000 Records (Erfolgsrate: 16.0%)
# 📊 Verarbeitet: 514,000 Records (Erfolgsrate: 16.0%)
# 📊 Verarbeitet: 515,000 Records (Erfolgsrate: 16.2%)
# 📊 Verarbeitet: 515,000 Records (Erfolgsrate: 16.2%)
# 📊 Verarbeitet: 516,000 Records (Erfolgsrate: 16.3%)
# 📊 Verarbeitet: 516,000 Records (Erfolgsrate: 16.3%)
# 📊 Verarbeitet: 517,000 Records (Erfolgsrate: 16.5%)
# 📊 Verarbeitet: 517,000 Records (Erfolgsrate: 16.5%)
# 📊 Verarbeitet: 518,000 Records (Erfolgsrate: 16.6%)
# 📊 Verarbeitet: 518,000 Records (Erfolgsrate: 16.6%)
#
# ✅ MAB2-Parsing abgeschlossen:
#    📋 Total Records: 518,954
#    ✅ Erfolgreich geparst: 86,957
#    ❌ Fehler: 431,980
#
# ✅ MAB2-Parsing abgeschlossen:
#    📋 Total Records: 518,954
#    ✅ Erfolgreich geparst: 86,957
#    ❌ Fehler: 431,980
#    📊 DataFrame: 86,957 Zeilen, 13 Spalten
#
# 📊 === MAB2 DATENANALYSE ===
# 📋 Datensatz: 86,957 Records
#    📊 DataFrame: 86,957 Zeilen, 13 Spalten
#
# 📊 === MAB2 DATENANALYSE ===
# 📋 Datensatz: 86,957 Records
#
# 🔍 === VOLLSTÄNDIGKEITS-ANALYSE ===
# 📖 Records mit Titel: 85,959 (98.9%)
#
# 🔍 === VOLLSTÄNDIGKEITS-ANALYSE ===
# 📖 Records mit Titel: 85,959 (98.9%)
# ✍️  Records mit Autor: 81,791 (94.1%)
# 📅 Records mit Jahr: 67,369 (77.5%)
# 📚 Records mit ISBN: 48,759 (56.1%)
# ✍️  Records mit Autor: 81,791 (94.1%)
# 📅 Records mit Jahr: 67,369 (77.5%)
# 📚 Records mit ISBN: 48,759 (56.1%)
#
# 📅 === JAHRES-VERTEILUNG ===
# Ältestes Jahr: 1538.0
# Neuestes Jahr: 2024.0
# Durchschnitt: 1993.6
#
# ✍️  === TOP 5 AUTOREN ===
#
# 📅 === JAHRES-VERTEILUNG ===
# Ältestes Jahr: 1538.0
# Neuestes Jahr: 2024.0
# Durchschnitt: 1993.6
#
# ✍️  === TOP 5 AUTOREN ===
#    Technische Universität Bergakademie Freiberg: 523 Records
#    Scheidhauer, Johann Andreas: 140 Records
#    Staudinger, Julius ¬von¬: 96 Records
#    Leal Filho, Walter: 87 Records
#    Aluminium-Zentrale <Düsseldorf>: 75 Records
#    Technische Universität Bergakademie Freiberg: 523 Records
#    Scheidhauer, Johann Andreas: 140 Records
#    Staudinger, Julius ¬von¬: 96 Records
#    Leal Filho, Walter: 87 Records
#    Aluminium-Zentrale <Düsseldorf>: 75 Records
# 📊 Analyse des Gesamtdatenbestands:
#
# 🔍 Beispiel-Records aus dem Gesamtdatenbestand:
#       id                                                  title                      authors_str    year  isbn    place
# 0  00499  Geologische Karte von Bayern <1:25000> : Geologisc...  Bayern / Geologisches Landesamt     NaN  None  München
# 1  00379                           Caesar's wife : Patrick Gale                    Gale, Patrick     NaN  None     None
# 2  00919                         Medienbildung und Gesellschaft                             None  2006.0  None     None
